# %%
import matplotlib.pyplot as plt
import torch
import os

# %%
os.chdir(os.path.join(os.path.expanduser("~"), "Nystromformer/Nystrom-Simple-Transformer/"))

# %%
checkpoint_nystrom = torch.load(os.path.join("Checkpoints", "Checkpoint5000_nystrom.pkl"))
checkpoint_baseline = torch.load(os.path.join("Checkpoints", "Checkpoint5000_baseline.pkl"))
plt.plot(checkpoint_nystrom["train_losses"], label='Nystrom')
plt.plot(checkpoint_baseline["train_losses"], label='Simple')
plt.legend()
plt.show()

# %% [markdown]
# ### Extra
# Train/Test plots

# %%
checkpoint = torch.load(os.path.join("Checkpoints", "Checkpoint5000_nystrom.pkl"))
plt.plot(checkpoint["train_losses"])
plt.plot(checkpoint["test_losses"])
plt.show()

# %%
checkpoint = torch.load(os.path.join("Checkpoints", "Checkpoint5000_baseline.pkl"))
plt.plot(checkpoint["train_losses"])
plt.plot(checkpoint["test_losses"])
plt.show()
